# %%
import pandas as pd
import numpy as np
import json
import sys
import pyecharts
sys.path.append('..')

# %%
from src import *
yelp_path = '../data/yelp_academic_dataset_review.csv'
yelp_business_path = '../data/yelp_academic_dataset_business.csv'
with open('../assets/yelp_dtype.json', 'r') as json_file:
    yelp_dtype = json.load(json_file)

with open('../assets/yelp_business_dtype.json', 'r') as json_file:
    yelp_business_dtype = json.load(json_file)

# %%
yelp_path = '../data/yelp_academic_dataset_review.csv'
yelp_business_path = '../data/yelp_academic_dataset_business.csv'
yelp = pd.read_csv(
    yelp_path, encoding='utf-8', dtype=yelp_dtype)
yelp_business = pd.read_csv(
    yelp_business_path, encoding='utf-8', dtype=yelp_business_dtype)

# %% [markdown]
# 这里查看每个城市的不同种类数量

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
PingFang = FontProperties(fname='../assets/PingFang.ttc')
plt.style.use('ggplot')

# %%
# from src.color_generator import fetch_colors, append_to_json_file
# hex_color = 'E5E5E5'  # 要查询的HEX颜色代码
# result = fetch_colors(hex_color)  # 假设这是 color_generator 中的一个函数
# append_to_json_file(result, '../assets/Palette.json')  # 假设这是 color_generator 中的一个函数

color_code = '#E5E5E5'
palette_key = 'Twisted Spot Palette'

try:
    with open('../assets/Palette.json', 'r') as file:
        data = json.load(file)
    if color_code in data:
        main_color = data[color_code].get(palette_key, [])
        print("Main Color Palette:", main_color)
except FileNotFoundError:
    ImportError("JSON文件格式不正确。")
except json.JSONDecodeError:
    ImportError("JSON文件格式不正确。")
# Out:
# Main Color Palette: ['#00754B', '#C8FCEA', '#6A9A8B']

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
import pandas as pd

# 按城市分组并计算商家数量
yelp_business_groups = yelp_business.groupby('city').count()
yelp_business_city = yelp_business_groups['name']
yelp_business_city_sorted = yelp_business_city.sort_values(ascending=False)

# 提取前30个城市的商家数量
top_30_cities = yelp_business_city_sorted[:30]

# 使用pyecharts绘制柱状图
bar = (
    Bar()
    .add_xaxis(top_30_cities.index.tolist())
    .add_yaxis("商家数量", top_30_cities.values.tolist(), color=main_color[0])
    .set_global_opts(
        title_opts=opts.TitleOpts(title="每个城市的商家数量（前30名）", subtitle="", title_textstyle_opts=opts.TextStyleOpts(font_family="PingFang", font_size=16)),
        xaxis_opts=opts.AxisOpts(name="城市", axislabel_opts=opts.LabelOpts(rotate=45, font_family="PingFang")),
        yaxis_opts=opts.AxisOpts(name="商家数量", axislabel_opts=opts.LabelOpts(font_family="PingFang")),
        datazoom_opts=[opts.DataZoomOpts()],
    )
)

# 渲染图表
bar.render("../images/01_每个城市的商家数量.html")
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c314963ebd834b2494b30a4a188df929" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c314963ebd834b2494b30a4a188df929 = echarts.init(
#                     document.getElementById('c314963ebd834b2494b30a4a188df929'), 'white', {renderer: 'canvas'});
#                 var option_c314963ebd834b2494b30a4a188df929 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#00754B",
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6\u6570\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 12022,
#                 7499,
#                 3605,
#                 2887,
#                 2041,
#                 2025,
#                 1914,
#                 1637,
#                 1630,
#                 1196,
#                 1049,
#                 591,
#                 521,
#                 391,
#                 308,
#                 258,
#                 203,
#                 164,
#                 150,
#                 149,
#                 127,
#                 114,
#                 101,
#                 92,
#                 91,
#                 87,
#                 81,
#                 79,
#                 77,
#                 72
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6\u6570\u91cf"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "name": "\u57ce\u5e02",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "rotate": 45,
#                 "margin": 8,
#                 "fontFamily": "PingFang"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "Las Vegas",
#                 "Phoenix",
#                 "Scottsdale",
#                 "Edinburgh",
#                 "Mesa",
#                 "Tempe",
#                 "Henderson",
#                 "Chandler",
#                 "Madison",
#                 "Glendale",
#                 "Gilbert",
#                 "Peoria",
#                 "North Las Vegas",
#                 "Surprise",
#                 "Goodyear",
#                 "Avondale",
#                 "Queen Creek",
#                 "Waterloo",
#                 "Middleton",
#                 "Cave Creek",
#                 "Kitchener",
#                 "Fountain Hills",
#                 "Casa Grande",
#                 "Fitchburg",
#                 "Apache Junction",
#                 "Maricopa",
#                 "Paradise Valley",
#                 "Buckeye",
#                 "Sun City",
#                 "Sun Prairie"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u5546\u5bb6\u6570\u91cf",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "margin": 8,
#                 "fontFamily": "PingFang"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u6bcf\u4e2a\u57ce\u5e02\u7684\u5546\u5bb6\u6570\u91cf\uff08\u524d30\u540d\uff09",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false,
#             "textStyle": {
#                 "fontFamily": "PingFang",
#                 "fontSize": 16
#             }
#         }
#     ],
#     "dataZoom": [
#         {
#             "show": true,
#             "type": "slider",
#             "showDetail": true,
#             "showDataShadow": true,
#             "realtime": true,
#             "start": 20,
#             "end": 80,
#             "orient": "horizontal",
#             "zoomLock": false,
#             "filterMode": "filter"
#         }
#     ]
# };
#                 chart_c314963ebd834b2494b30a4a188df929.setOption(option_c314963ebd834b2494b30a4a188df929);
#         });
#     </script>

# %% [markdown]
# 查看不同类型的企业及其数量

# %%
# 计算每个类别的出现次数
categories_dict = {}
for i in yelp_business.categories:
    cat = str(i).split(',')
    for j in cat:
        if j not in categories_dict.keys():
            categories_dict[j] = 1
        else:
            categories_dict[j] += 1

categories_series = pd.Series(categories_dict)
categories_series.sort_values(ascending=False, inplace=True)

# 提取前30个类别的数量
top_30_categories = categories_series[:30]

# 使用pyecharts绘制柱状图
bar = (
    Bar()
    .add_xaxis(top_30_categories.index.tolist())
    .add_yaxis("数量", top_30_categories.values.tolist(), color=main_color[0])
    .set_global_opts(
        title_opts=opts.TitleOpts(title="最受欢迎的商家类别（前30名）", subtitle="", title_textstyle_opts=opts.TextStyleOpts(font_family="PingFang", font_size=16)),
        xaxis_opts=opts.AxisOpts(name="类别", axislabel_opts=opts.LabelOpts(rotate=45, font_family="PingFang", font_size=8)),
        yaxis_opts=opts.AxisOpts(name="数量", axislabel_opts=opts.LabelOpts(font_family="PingFang")),
        datazoom_opts=[opts.DataZoomOpts()],
    )
)

# 渲染图表
bar.render("../images/02_最受欢迎的商家类别.html")
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3f9fe2ce650e42669af908ca6b7d2015" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3f9fe2ce650e42669af908ca6b7d2015 = echarts.init(
#                     document.getElementById('3f9fe2ce650e42669af908ca6b7d2015'), 'white', {renderer: 'canvas'});
#                 var option_3f9fe2ce650e42669af908ca6b7d2015 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#00754B",
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6570\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 1230,
#                 709,
#                 681,
#                 665,
#                 632,
#                 616,
#                 518,
#                 493,
#                 444,
#                 431,
#                 420,
#                 420,
#                 399,
#                 374,
#                 345,
#                 342,
#                 339,
#                 297,
#                 276,
#                 269,
#                 250,
#                 241,
#                 241,
#                 235,
#                 223,
#                 223,
#                 218,
#                 204,
#                 203,
#                 197
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6570\u91cf"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "name": "\u7c7b\u522b",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "rotate": 45,
#                 "margin": 8,
#                 "fontSize": 8,
#                 "fontFamily": "PingFang"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "Mexican;Restaurants",
#                 "Pizza;Restaurants",
#                 "Beauty & Spas;Nail Salons",
#                 "Food;Coffee & Tea",
#                 "Hotels & Travel;Event Planning & Services;Hotels",
#                 "Chinese;Restaurants",
#                 "Fast Food;Restaurants",
#                 "Sandwiches;Restaurants",
#                 "Hair Salons;Beauty & Spas",
#                 "American (Traditional);Restaurants",
#                 "Food;Grocery",
#                 "Auto Repair;Automotive",
#                 "Restaurants;Italian",
#                 "Food;Ice Cream & Frozen Yogurt",
#                 " Mags",
#                 "American (New);Restaurants",
#                 "nan",
#                 "Home Services;Real Estate;Apartments",
#                 "Local Services;Dry Cleaning & Laundry",
#                 "Department Stores;Fashion;Shopping",
#                 "Pubs;Bars;Nightlife",
#                 "Burgers;Fast Food;Restaurants",
#                 "Food;Beer",
#                 "Veterinarians;Pets",
#                 "Burgers;Restaurants",
#                 "Restaurants",
#                 "Barbers;Beauty & Spas",
#                 "Thai;Restaurants",
#                 "Banks & Credit Unions;Financial Services",
#                 "Health & Medical;Dentists;General Dentistry"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u6570\u91cf",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "margin": 8,
#                 "fontFamily": "PingFang"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u6700\u53d7\u6b22\u8fce\u7684\u5546\u5bb6\u7c7b\u522b\uff08\u524d30\u540d\uff09",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false,
#             "textStyle": {
#                 "fontFamily": "PingFang",
#                 "fontSize": 16
#             }
#         }
#     ],
#     "dataZoom": [
#         {
#             "show": true,
#             "type": "slider",
#             "showDetail": true,
#             "showDataShadow": true,
#             "realtime": true,
#             "start": 20,
#             "end": 80,
#             "orient": "horizontal",
#             "zoomLock": false,
#             "filterMode": "filter"
#         }
#     ]
# };
#                 chart_3f9fe2ce650e42669af908ca6b7d2015.setOption(option_3f9fe2ce650e42669af908ca6b7d2015);
#         });
#     </script>

# %% [markdown]
# ## 1.3. 商业和城市有序对及其计数

# %%
# 创建business_city字典，用于存储城市和分类的商家数量
business_city = {}
n = len(yelp_business)

for i in range(n):
    k1 = str(yelp_business.categories.iloc[i]).split(',')
    k2 = yelp_business.city.iloc[i]
    for j in k1:
        k = (j.strip(), k2)  # 去掉类别字符串中的空格
        if k not in business_city.keys():
            business_city[k] = 1
        else:
            business_city[k] += 1

# 将字典转换为Series并排序
business_city_series = pd.Series(business_city)
business_city_series.sort_values(ascending=False, inplace=True)

# 提取前30个城市-分类的组合数量
top_30_business_city = business_city_series[:30]

# 使用pyecharts绘制柱状图
bar = (
    Bar()
    .add_xaxis([f"{k[1]} - {k[0]}" for k in top_30_business_city.index])
    .add_yaxis("商家数量", top_30_business_city.values.tolist(), color=main_color[0])
    .set_global_opts(
        title_opts=opts.TitleOpts(title="城市和商家类别组合数量（前30名）", subtitle="", title_textstyle_opts=opts.TextStyleOpts(font_family="PingFang", font_size=16)),
        xaxis_opts=opts.AxisOpts(name="城市-分类", axislabel_opts=opts.LabelOpts(rotate=45, font_family="PingFang", font_size=8)),
        yaxis_opts=opts.AxisOpts(name="商家数量", axislabel_opts=opts.LabelOpts(font_family="PingFang")),
        datazoom_opts=[opts.DataZoomOpts()],
    )
)

# 渲染图表
bar.render("../images/03_城市和商家类别组合数量.html")
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="7817508723204b71a665ec3d134e1730" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_7817508723204b71a665ec3d134e1730 = echarts.init(
#                     document.getElementById('7817508723204b71a665ec3d134e1730'), 'white', {renderer: 'canvas'});
#                 var option_7817508723204b71a665ec3d134e1730 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#00754B",
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6\u6570\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 305,
#                 299,
#                 199,
#                 192,
#                 190,
#                 168,
#                 158,
#                 153,
#                 149,
#                 144,
#                 144,
#                 123,
#                 119,
#                 115,
#                 114,
#                 109,
#                 109,
#                 109,
#                 109,
#                 102,
#                 102,
#                 100,
#                 99,
#                 96,
#                 91,
#                 90,
#                 89,
#                 87,
#                 85,
#                 84
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6\u6570\u91cf"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "name": "\u57ce\u5e02-\u5206\u7c7b",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "rotate": 45,
#                 "margin": 8,
#                 "fontSize": 8,
#                 "fontFamily": "PingFang"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "Phoenix - Mexican;Restaurants",
#                 "Las Vegas - Mexican;Restaurants",
#                 "Edinburgh - Pubs;Bars;Nightlife",
#                 "Las Vegas - Pizza;Restaurants",
#                 "Las Vegas - Beauty & Spas;Nail Salons",
#                 "Las Vegas - Food;Coffee & Tea",
#                 "Las Vegas - Fast Food;Restaurants",
#                 "Las Vegas - Chinese;Restaurants",
#                 "Las Vegas - Sandwiches;Restaurants",
#                 "Las Vegas - Hotels & Travel;Event Planning & Services;Hotels",
#                 "Las Vegas - Arts & Entertainment;Performing Arts",
#                 "Phoenix - Hotels & Travel;Event Planning & Services;Hotels",
#                 "Las Vegas - nan",
#                 "Las Vegas - American (Traditional);Restaurants",
#                 "Las Vegas - Food;Grocery",
#                 "Phoenix - Beauty & Spas;Nail Salons",
#                 "Las Vegas - Auto Repair;Automotive",
#                 "Phoenix - Chinese;Restaurants",
#                 "Phoenix - Food;Coffee & Tea",
#                 "Las Vegas - Restaurants;Italian",
#                 "Phoenix - Auto Repair;Automotive",
#                 "Las Vegas - Hair Salons;Beauty & Spas",
#                 "Phoenix - Pizza;Restaurants",
#                 "Las Vegas - Food;Ice Cream & Frozen Yogurt",
#                 "Phoenix - Sandwiches;Restaurants",
#                 "Las Vegas - Bars;Nightlife;Lounges",
#                 "Edinburgh - Food;Coffee & Tea",
#                 "Mesa - Mexican;Restaurants",
#                 "Las Vegas - Local Services;Dry Cleaning & Laundry",
#                 "Phoenix - Home Services;Real Estate;Apartments"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u5546\u5bb6\u6570\u91cf",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "margin": 8,
#                 "fontFamily": "PingFang"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u57ce\u5e02\u548c\u5546\u5bb6\u7c7b\u522b\u7ec4\u5408\u6570\u91cf\uff08\u524d30\u540d\uff09",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false,
#             "textStyle": {
#                 "fontFamily": "PingFang",
#                 "fontSize": 16
#             }
#         }
#     ],
#     "dataZoom": [
#         {
#             "show": true,
#             "type": "slider",
#             "showDetail": true,
#             "showDataShadow": true,
#             "realtime": true,
#             "start": 20,
#             "end": 80,
#             "orient": "horizontal",
#             "zoomLock": false,
#             "filterMode": "filter"
#         }
#     ]
# };

# %% [markdown]
# 可以看出，Yelp 上列出的多数商家是餐馆、购物场所和娱乐中心。对于这组数据（来自 Yelp 网站），拥有最多商家的主要城市是`Las Vegas`, `Phoenix`,和`Scottsdale`。

# %% [markdown]
# # 2. 清理评论数据

# %% [markdown]
# ## 2.1 删除不需要的列
# - `text`: 评论文本,
# - `useful`: 认为有用的人数,
# - `date`: 日期
#
# 剩下的列是 `user_id`, `business_id` 和 `stars`.

# %%
yelp_cleaned = yelp.drop(['text',
                          'votes.useful',
                          'votes.cool',
                          'date',
                          'votes.funny'], axis=1)
yelp_cleaned.head()
# Out:
#                   user_id               review_id             business_id  \
# 0  Xqd0DzHaiyRqVH3WRG7hzg  15SdjuK7DmYqUAj6rjGowg  vcNAWiLM4dR7D2nwwJ7nCA
# 1  H1kH6QZV7Le4zqTRNxoZow  RF6UnRTtG7tWMcrO2GEoAg  vcNAWiLM4dR7D2nwwJ7nCA
# 2  zvJCcrpm2yOZrxKffwGQLA  -TsVN230RCkLYKBeLsuz7A  vcNAWiLM4dR7D2nwwJ7nCA
# 3  KBLW4wJA_fwoWmMhiHRVOA  dNocEAyUucjT371NNND41Q  vcNAWiLM4dR7D2nwwJ7nCA
# 4  zvJCcrpm2yOZrxKffwGQLA  ebcN2aqmNUuYNoyvQErgnA  vcNAWiLM4dR7D2nwwJ7nCA
#
#    stars    type
# 0      5  review
# 1      2  review
# 2      4  review
# 3      4  review
# 4      4  review

# %% [markdown]
# ## 2.2 合并数据
# 合并业务数据`yelp_academic_dataset_business.csv`与评论数据`yelp_academic_dataset_review.csv`

# %% [markdown]
# 将业务数据和评论数据利用 'business_id' 为主键合并。像business的 'city' 和 'categories' 这样的信息是从业务数据文件中获取的。

# %%
yelp_full = yelp_cleaned.merge(
    yelp_business[['city',
                   'categories',
                   'business_id']], how='inner', on='business_id')

df = yelp_full.dropna()

# %% [markdown]
# ## 2.3. 获取评论数量最多的前30名业务类别和城市

# %%
# 获取前30个城市和商家类别组合的评论数量
review_business_city = get_top_m_num_reviews_for_city_and_business(df, 30)

# 使用pyecharts绘制柱状图
bar = (
    Bar()
    .add_xaxis([f"{k[1]} - {k[0]}" for k in review_business_city.index])
    .add_yaxis("评论数量", review_business_city.values.tolist(), color=main_color[0])
    .set_global_opts(
        title_opts=opts.TitleOpts(title="获得评论最多的城市和商家类别组合（前30名）", subtitle="", title_textstyle_opts=opts.TextStyleOpts(font_family="PingFang", font_size=16)),
        xaxis_opts=opts.AxisOpts(name="城市-业务类别", axislabel_opts=opts.LabelOpts(rotate=45, font_family="PingFang", font_size=8)),
        yaxis_opts=opts.AxisOpts(name="评论数量", axislabel_opts=opts.LabelOpts(font_family="PingFang")),
        datazoom_opts=[opts.DataZoomOpts()],
    )
)

# 渲染图表
bar.render("../images/04_获得评论最多的城市和商家类别组合.html")
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="265151e8e6384e5588a01668280dae21" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_265151e8e6384e5588a01668280dae21 = echarts.init(
#                     document.getElementById('265151e8e6384e5588a01668280dae21'), 'white', {renderer: 'canvas'});
#                 var option_265151e8e6384e5588a01668280dae21 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#00754B",
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u8bc4\u8bba\u6570\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 33381,
#                 19959,
#                 14765,
#                 11852,
#                 10283,
#                 9898,
#                 9592,
#                 9564,
#                 9385,
#                 8791,
#                 8490,
#                 7566,
#                 7009,
#                 6669,
#                 6399,
#                 6294,
#                 6119,
#                 5644,
#                 5182,
#                 4594,
#                 4382,
#                 4328,
#                 3992,
#                 3918,
#                 3695,
#                 3453,
#                 3351,
#                 3308,
#                 3303,
#                 3171
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8bc4\u8bba\u6570\u91cf"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "name": "\u57ce\u5e02-\u4e1a\u52a1\u7c7b\u522b",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "rotate": 45,
#                 "margin": 8,
#                 "fontSize": 8,
#                 "fontFamily": "PingFang"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "Las Vegas - Hotels & Travel;Arts & Entertainment;Casinos;Event Planning & Services;Hotels",
#                 "Las Vegas - Buffets;Restaurants",
#                 "Las Vegas - Mexican;Restaurants",
#                 "Phoenix - Mexican;Restaurants",
#                 "Las Vegas - Arts & Entertainment;Performing Arts",
#                 "Las Vegas - Steakhouses;Restaurants",
#                 "Las Vegas - Restaurants;Italian",
#                 "Las Vegas - Sushi Bars;Japanese;Restaurants",
#                 "Las Vegas - Hotels & Travel;Event Planning & Services;Hotels",
#                 "Las Vegas - American (Traditional);Restaurants",
#                 "Las Vegas - Nightlife;Dance Clubs",
#                 "Las Vegas - Pizza;Restaurants",
#                 "Las Vegas - Burgers;Restaurants",
#                 "Las Vegas - American (New);Restaurants",
#                 "Las Vegas - Chinese;Restaurants",
#                 "Las Vegas - Thai;Restaurants",
#                 "Las Vegas - Sandwiches;Restaurants",
#                 "Las Vegas - Japanese;Restaurants",
#                 "Phoenix - American (New);Restaurants",
#                 "Las Vegas - Breakfast & Brunch;American (New);Restaurants",
#                 "Phoenix - Italian;Pizza;Sandwiches;Restaurants",
#                 "Las Vegas - Bars;Nightlife;Lounges",
#                 "Scottsdale - Mexican;Restaurants",
#                 "Las Vegas - Vietnamese;Restaurants",
#                 "Las Vegas - Breakfast & Brunch;Steakhouses;French;Restaurants",
#                 "Las Vegas - Food;Coffee & Tea",
#                 "Las Vegas - Sushi Bars;Restaurants",
#                 "Las Vegas - Arts & Entertainment;Resorts;Casinos;Event Planning & Services;Hotels & Travel;Hotels",
#                 "Las Vegas - French;Restaurants",
#                 "Las Vegas - Lounges;Bars;Nightlife;Dance Clubs"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u8bc4\u8bba\u6570\u91cf",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "margin": 8,
#                 "fontFamily": "PingFang"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u83b7\u5f97\u8bc4\u8bba\u6700\u591a\u7684\u57ce\u5e02\u548c\u5546\u5bb6\u7c7b\u522b\u7ec4\u5408\uff08\u524d30\u540d\uff09",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false,
#             "textStyle": {
#                 "fontFamily": "PingFang",
#                 "fontSize": 16
#             }
#         }
#     ],
#     "dataZoom": [
#         {
#             "show": true,
#             "type": "slider",

# %%
df.to_csv('../data/Yelp_final.csv', index=False)
